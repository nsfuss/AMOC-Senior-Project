# %%
import numpy as np
import matplotlib.pyplot as plt
import matplotlib as mpl
import scipy.integrate as integ

import requests
request = requests.get("https://raw.githubusercontent.com/nsfuss/AMOC-Senior-Project/refs/heads/main/functions.py")
with open("functions.py", "wb") as f:
  f.write(request.content)
from functions import *

mpl.rc('xtick', direction='in', top=True)
mpl.rc('ytick', direction='in', right=True)
mpl.rc('xtick.minor', visible=True)
mpl.rc('ytick.minor', visible=True)

# %% [markdown]
# Need all H such that $\frac{H\beta}{k \alpha^2  \Delta T^2} \leq \frac{1}{4}$ because this will make sure $\Delta S \in ℝ$ for our equilbrium solutions. While I could make this not needed it would involve a lot more coding to exclude the exceptions so for now we will just do math to make sure all of the equilibrium solutions will exist given the basic parameters. As we are letting everything but H be set at 1 for now H must be less than 1/4

# %%
beta = 2.5
alpha = 1 
deltaT = 1
k = 2
Args = [beta,alpha,deltaT,k]
H = getH(Args,1000)
qs = q_H(H, Args)
plt.plot(H, qs[1], color='b',label=r'Increased $k$')
plt.plot(H, qs[0], color='b')
plt.plot(H, qs[2], color='b')


beta = 4
alpha = 1 
deltaT = 1
k = 1
Args = [beta,alpha,deltaT,k]
H = getH(Args,1000)
qs = q_H(H, Args)
plt.plot(H, qs[1], color='c',label=r'Increased $\beta$')
plt.plot(H, qs[0], color='c')
plt.plot(H, qs[2], color='c')

beta = 2.5
alpha = 1 
deltaT = 2
k = 1
Args = [beta,alpha,deltaT,k]
H = getH(Args,1000)
qs = q_H(H, Args)
plt.plot(H, qs[1], color='r',label=r'Increased $\alpha$')
plt.plot(H, qs[0], color='r')
plt.plot(H, qs[2], color='r')

plt.title('Flow Rate vs Rate of Freshwater Forcing')
plt.legend()

# %%
beta = 2.5
alpha = 1 
deltaT = 1
k = 1
Args = [beta,alpha,deltaT,k]
H = getH(Args,1000)
qs = q_H(H, Args)

plt.plot(H, qs[1], color='r',label='Stable')
plt.plot(H, qs[0], color='g',label='Unstable')
plt.plot(H, qs[2], color='c',label='Stable')
plt.title(r'$\beta =$%.1f, $\alpha =$%.1f, $\Delta T =$%.1f, and $k =$%.1f' % (beta,alpha,deltaT,k))
plt.suptitle('Flow Rate vs Rate of Freshwater Forcing')
plt.xlabel('H')
plt.ylabel('Q')
leg = plt.legend()
